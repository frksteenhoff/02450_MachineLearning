# %% [markdown]
# # Week 12 - The apriori algorithm

# %%
import numpy as np
from subprocess import call
import re
import os

filename = 'Data\courses.txt'
minSup = 25
minConf = 100
maxRule = 4

# Run Apriori Algorithm
print('Mining for frequent itemsets by the Apriori algorithm')
status1 = call('Tools/apriori.exe -f"," -s{0} -v"[Sup. %S]" {1} apriori_temp1.txt'.format(minSup, filename))
if status1!=0:
    print('An error occured while calling apriori, a likely cause is that minSup was set to high such that no frequent itemsets were generated or spaces are included in the path to the apriori files.')
    exit()
if minConf>0:
    print('Mining for associations by the Apriori algorithm')
    status2 = call('Tools/apriori.exe -tr -f"," -n{0} -c{1} -s{2} -v"[Conf. %C,Sup. %S]" {3} apriori_temp2.txt'.format(maxRule, minConf, minSup, filename))
    if status2!=0:
        print('An error occured while calling apriori')
        exit()
print('Apriori analysis done, extracting results')

# Extract information from stored files apriori_temp1.txt and apriori_temp2.txt
f = open('apriori_temp1.txt','r')
lines = f.readlines()
print lines
f.close()

# Extract Frequent Itemsets
FrequentItemsets = ['']*len(lines)
sup = np.zeros((len(lines),1))
for i,line in enumerate(lines):
    FrequentItemsets[i] = line[0:-1]
    sup[i] = re.findall(' [-+]?\d*\.\d+|\d+]', line)[0][1:-1]
os.remove('apriori_temp1.txt')
    
# Read the file
f = open('apriori_temp2.txt','r')
lines = f.readlines()
print lines
f.close()
# Extract Association rules
AssocRules = ['']*len(lines)
conf = np.zeros((len(lines),1))
for i,line in enumerate(lines):
    AssocRules[i] = line[0:-1]
    conf[i] = re.findall(' [-+]?\d*\.\d+|\d+,', line)[0][1:-1]
os.remove('apriori_temp2.txt')    

# sort (FrequentItemsets by support value, AssocRules by confidence value)
AssocRulesSorted = [AssocRules[item] for item in np.argsort(conf,axis=0).ravel()]
AssocRulesSorted.reverse()
FrequentItemsetsSorted = [FrequentItemsets[item] for item in np.argsort(sup,axis=0).ravel()]
FrequentItemsetsSorted.reverse()
    
# Print the results
import time; time.sleep(.5)    
print('\n')
print('RESULTS:\n')
print('Frequent itemsets:')
for i,item in enumerate(FrequentItemsetsSorted):
    print('Item: {0}'.format(item))
print('\n')

print('Association rules:')
for i,item in enumerate(AssocRulesSorted):
    print('Rule: {0}'.format(item))
# Out:
# Mining for frequent itemsets by the Apriori algorithm
# Mining for associations by the Apriori algorithm
# Apriori analysis done, extracting results
# ['6[Sup. 100]\n', '3 6 7[Sup. 50]\n', '3 6[Sup. 50]\n', '3 7[Sup. 50]\n', '3[Sup. 50]\n', '3 8 6 7 2[Sup. 33]\n', '3 8 6 7[Sup. 33]\n', '3 8 6 2[Sup. 33]\n', '3 8 6[Sup. 33]\n', '3 8 7 2[Sup. 33]\n', '3 8 7[Sup. 33]\n', '3 8 2[Sup. 33]\n', '3 8[Sup. 33]\n', '3 2 6 7[Sup. 33]\n', '3 2 6[Sup. 33]\n', '3 2 7[Sup. 33]\n', '3 2[Sup. 33]\n', '8 6 2[Sup. 67]\n', '8 6[Sup. 67]\n', '8 2[Sup. 67]\n', '8[Sup. 67]\n', '8 7 6 2[Sup. 50]\n', '8 7 6[Sup. 50]\n', '8 7 2[Sup. 50]\n', '8 7[Sup. 50]\n', '7 6[Sup. 83]\n', '7[Sup. 83]\n', '7 2 6[Sup. 67]\n', '7 2[Sup. 67]\n', '2 6[Sup. 83]\n', '2[Sup. 83]\n']
# ['6 <- [Conf. 100,Sup. 100]\n', '7 <- 3[Conf. 100,Sup. 50]\n', '6 <- 3[Conf. 100,Sup. 50]\n', '2 <- 8[Conf. 100,Sup. 67]\n', '6 <- 8[Conf. 100,Sup. 67]\n', '6 <- 7[Conf. 100,Sup. 83]\n', '6 <- 2[Conf. 100,Sup. 83]\n', '7 <- 3 8[Conf. 100,Sup. 33]\n', '2 <- 3 8[Conf. 100,Sup. 33]\n', '8 <- 3 2[Conf. 100,Sup. 33]\n', '6 <- 3 8[Conf. 100,Sup. 33]\n', '7 <- 3 2[Conf. 100,Sup. 33]\n', '6 <- 3 7[Conf. 100,Sup. 50]\n', '7 <- 3 6[Conf. 100,Sup. 50]\n', '6 <- 3 2[Conf. 100,Sup. 33]\n', '2 <- 8 7[Conf. 100,Sup. 50]\n', '6 <- 8 7[Conf. 100,Sup. 50]\n', '6 <- 8 2[Conf. 100,Sup. 67]\n', '2 <- 8 6[Conf. 100,Sup. 67]\n', '6 <- 7 2[Conf. 100,Sup. 67]\n', '2 <- 3 8 7[Conf. 100,Sup. 33]\n', '7 <- 3 8 2[Conf. 100,Sup. 33]\n', '8 <- 3 7 2[Conf. 100,Sup. 33]\n', '6 <- 3 8 7[Conf. 100,Sup. 33]\n', '7 <- 3 8 6[Conf. 100,Sup. 33]\n', '6 <- 3 8 2[Conf. 100,Sup. 33]\n', '2 <- 3 8 6[Conf. 100,Sup. 33]\n', '8 <- 3 2 6[Conf. 100,Sup. 33]\n', '6 <- 3 7 2[Conf. 100,Sup. 33]\n', '7 <- 3 2 6[Conf. 100,Sup. 33]\n', '6 <- 8 7 2[Conf. 100,Sup. 50]\n', '2 <- 8 7 6[Conf. 100,Sup. 50]\n']
#
#
# RESULTS:
#
# Frequent itemsets:
# Item: 7 2[Sup. 67]
# Item: 7 2 6[Sup. 67]
# Item: 8[Sup. 67]
# Item: 8 2[Sup. 67]
# Item: 8 6[Sup. 67]
# Item: 8 6 2[Sup. 67]
# Item: 2[Sup. 83]
# Item: 3 2 6 7[Sup. 33]
# Item: 3 8 6 7 2[Sup. 33]
# Item: 3 8 6 7[Sup. 33]
# Item: 3 8 6 2[Sup. 33]
# Item: 3 8 6[Sup. 33]
# Item: 3 8 7 2[Sup. 33]
# Item: 3 8 7[Sup. 33]
# Item: 3 8 2[Sup. 33]
# Item: 3 8[Sup. 33]
# Item: 3 2 7[Sup. 33]
# Item: 3 2 6[Sup. 33]
# Item: 2 6[Sup. 83]
# Item: 3 2[Sup. 33]
# Item: 7 6[Sup. 83]
# Item: 7[Sup. 83]
# Item: 8 7 6 2[Sup. 50]
# Item: 8 7 6[Sup. 50]
# Item: 8 7 2[Sup. 50]
# Item: 8 7[Sup. 50]
# Item: 3[Sup. 50]
# Item: 3 7[Sup. 50]
# Item: 3 6[Sup. 50]
# Item: 3 6 7[Sup. 50]
# Item: 6[Sup. 100]
#
#
# Association rules:
# Rule: 2 <- 8 7 6[Conf. 100,Sup. 50]
# Rule: 6 <- 8 7 2[Conf. 100,Sup. 50]
# Rule: 7 <- 3[Conf. 100,Sup. 50]
# Rule: 6 <- 3[Conf. 100,Sup. 50]
# Rule: 2 <- 8[Conf. 100,Sup. 67]
# Rule: 6 <- 8[Conf. 100,Sup. 67]
# Rule: 6 <- 7[Conf. 100,Sup. 83]
# Rule: 6 <- 2[Conf. 100,Sup. 83]
# Rule: 7 <- 3 8[Conf. 100,Sup. 33]
# Rule: 2 <- 3 8[Conf. 100,Sup. 33]
# Rule: 8 <- 3 2[Conf. 100,Sup. 33]
# Rule: 6 <- 3 8[Conf. 100,Sup. 33]
# Rule: 7 <- 3 2[Conf. 100,Sup. 33]
# Rule: 6 <- 3 7[Conf. 100,Sup. 50]
# Rule: 7 <- 3 6[Conf. 100,Sup. 50]
# Rule: 6 <- 3 2[Conf. 100,Sup. 33]
# Rule: 2 <- 8 7[Conf. 100,Sup. 50]
# Rule: 6 <- 8 7[Conf. 100,Sup. 50]
# Rule: 6 <- 8 2[Conf. 100,Sup. 67]
# Rule: 2 <- 8 6[Conf. 100,Sup. 67]
# Rule: 6 <- 7 2[Conf. 100,Sup. 67]
# Rule: 2 <- 3 8 7[Conf. 100,Sup. 33]
# Rule: 7 <- 3 8 2[Conf. 100,Sup. 33]
# Rule: 8 <- 3 7 2[Conf. 100,Sup. 33]
# Rule: 6 <- 3 8 7[Conf. 100,Sup. 33]
# Rule: 7 <- 3 8 6[Conf. 100,Sup. 33]
# Rule: 6 <- 3 8 2[Conf. 100,Sup. 33]
# Rule: 2 <- 3 8 6[Conf. 100,Sup. 33]
# Rule: 8 <- 3 2 6[Conf. 100,Sup. 33]
# Rule: 6 <- 3 7 2[Conf. 100,Sup. 33]
# Rule: 7 <- 3 2 6[Conf. 100,Sup. 33]
# Rule: 6 <- [Conf. 100,Sup. 100]
