# %% [markdown]
# # Insert header

# %% [markdown]
# ## Working examples

# %% [markdown]
# ## Exercises

# %% [markdown]
# Imports

# %%
from matplotlib.pyplot import (figure, hold, plot, title, xlabel, ylabel, 
                               colorbar, imshow, xticks, yticks, show)
from scipy.io import loadmat
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from sklearn import cross_validation
import numpy as np
# %matplotlib inline

# %% [markdown]
# Exercise 7.1.1

# %%
# exercise 7.1.1
# Load Matlab data file and extract variables of interest
mat_data = loadmat('Data/synth1.mat')
X = mat_data['X']
X_train = mat_data['X_train']
X_test = mat_data['X_test']
y = mat_data['y'].squeeze()
y_train = mat_data['y_train'].squeeze()
y_test = mat_data['y_test'].squeeze()
attributeNames = [name[0] for name in mat_data['attributeNames'].squeeze()]
classNames = [name[0][0] for name in mat_data['classNames']]
N, M = X.shape
C = len(classNames)


# Plot the training data points (color-coded) and test data points.
figure(1);
hold(True);
styles = ['.b', '.r', '.g', '.y']
for c in range(C):
    class_mask = (y_train==c)
    plot(X_train[class_mask,0], X_train[class_mask,1], styles[c])


# K-nearest neighbors
K=5

# Distance metric (corresponds to 2nd norm, euclidean distance).
# You can set dist=1 to obtain manhattan distance (cityblock distance).
dist=2

# Fit classifier and classify the test points
knclassifier = KNeighborsClassifier(n_neighbors=K, p=dist);
knclassifier.fit(X_train, y_train);
y_est = knclassifier.predict(X_test);


# Plot the classfication results
styles = ['ob', 'or', 'og', 'oy']
for c in range(C):
    class_mask = (y_est==c)
    plot(X_test[class_mask,0], X_test[class_mask,1], styles[c], markersize=10)
    plot(X_test[class_mask,0], X_test[class_mask,1], 'kx', markersize=8)
title('Synthetic data classification - KNN');

# Compute and plot confusion matrix
cm = confusion_matrix(y_test, y_est);
accuracy = 100*cm.diagonal().sum()/cm.sum(); error_rate = 100-accuracy;
figure(2);
imshow(cm, cmap='binary', interpolation='None');
colorbar()
xticks(range(C)); yticks(range(C));
xlabel('Predicted class'); ylabel('Actual class');
title('Confusion matrix (Accuracy: {0}%, Error Rate: {1}%)'.format(accuracy, error_rate));

show()

# %% [markdown]
# Exercise 7.1.2

# %%
# Maximum number of neighbors
L=40

CV = cross_validation.LeaveOneOut(N)
errors = np.zeros((N,L))
i=0
for train_index, test_index in CV:
    print('Crossvalidation fold: {0}/{1}'.format(i+1,N))    
    
    # extract training and test set for current CV fold
    X_train = X[train_index,:]
    y_train = y[train_index]
    X_test = X[test_index,:]
    y_test = y[test_index]

    # Fit classifier and classify the test points (consider 1 to 40 neighbors)
    for l in range(1,L+1):
        knclassifier = KNeighborsClassifier(n_neighbors=l);
        knclassifier.fit(X_train, y_train);
        y_est = knclassifier.predict(X_test);
        errors[i,l-1] = np.sum(y_est[0]!=y_test[0])

    i+=1
    
# Plot the classification error rate
figure()
plot(100*sum(errors,0)/N)
xlabel('Number of neighbors')
ylabel('Classification error rate (%)')
show()
# Out:
# Crossvalidation fold: 1/200
# Crossvalidation fold: 2/200
# Crossvalidation fold: 3/200
# Crossvalidation fold: 4/200
# Crossvalidation fold: 5/200
# Crossvalidation fold: 6/200
# Crossvalidation fold: 7/200
# Crossvalidation fold: 8/200
# Crossvalidation fold: 9/200
# Crossvalidation fold: 10/200
# Crossvalidation fold: 11/200
# Crossvalidation fold: 12/200
# Crossvalidation fold: 13/200
# Crossvalidation fold: 14/200
# Crossvalidation fold: 15/200
# Crossvalidation fold: 16/200
# Crossvalidation fold: 17/200
# Crossvalidation fold: 18/200
# Crossvalidation fold: 19/200
# Crossvalidation fold: 20/200
# Crossvalidation fold: 21/200
# Crossvalidation fold: 22/200
# Crossvalidation fold: 23/200
# Crossvalidation fold: 24/200
# Crossvalidation fold: 25/200
# Crossvalidation fold: 26/200
# Crossvalidation fold: 27/200
# Crossvalidation fold: 28/200
# Crossvalidation fold: 29/200
# Crossvalidation fold: 30/200
# Crossvalidation fold: 31/200
# Crossvalidation fold: 32/200
# Crossvalidation fold: 33/200
# Crossvalidation fold: 34/200
# Crossvalidation fold: 35/200
# Crossvalidation fold: 36/200
# Crossvalidation fold: 37/200
# Crossvalidation fold: 38/200
# Crossvalidation fold: 39/200
# Crossvalidation fold: 40/200
# Crossvalidation fold: 41/200
# Crossvalidation fold: 42/200
# Crossvalidation fold: 43/200
# Crossvalidation fold: 44/200
# Crossvalidation fold: 45/200
# Crossvalidation fold: 46/200
# Crossvalidation fold: 47/200
# Crossvalidation fold: 48/200
# Crossvalidation fold: 49/200
# Crossvalidation fold: 50/200
# Crossvalidation fold: 51/200
# Crossvalidation fold: 52/200
# Crossvalidation fold: 53/200
# Crossvalidation fold: 54/200
# Crossvalidation fold: 55/200
# Crossvalidation fold: 56/200
# Crossvalidation fold: 57/200
# Crossvalidation fold: 58/200
# Crossvalidation fold: 59/200
# Crossvalidation fold: 60/200
# Crossvalidation fold: 61/200
# Crossvalidation fold: 62/200
# Crossvalidation fold: 63/200
# Crossvalidation fold: 64/200
# Crossvalidation fold: 65/200
# Crossvalidation fold: 66/200
# Crossvalidation fold: 67/200
# Crossvalidation fold: 68/200
# Crossvalidation fold: 69/200
# Crossvalidation fold: 70/200
# Crossvalidation fold: 71/200
# Crossvalidation fold: 72/200
# Crossvalidation fold: 73/200
# Crossvalidation fold: 74/200
# Crossvalidation fold: 75/200
# Crossvalidation fold: 76/200
# Crossvalidation fold: 77/200
# Crossvalidation fold: 78/200
# Crossvalidation fold: 79/200
# Crossvalidation fold: 80/200
# Crossvalidation fold: 81/200
# Crossvalidation fold: 82/200
# Crossvalidation fold: 83/200
# Crossvalidation fold: 84/200
# Crossvalidation fold: 85/200
# Crossvalidation fold: 86/200
# Crossvalidation fold: 87/200
# Crossvalidation fold: 88/200
# Crossvalidation fold: 89/200
# Crossvalidation fold: 90/200
# Crossvalidation fold: 91/200
# Crossvalidation fold: 92/200
# Crossvalidation fold: 93/200
# Crossvalidation fold: 94/200
# Crossvalidation fold: 95/200
# Crossvalidation fold: 96/200
# Crossvalidation fold: 97/200
# Crossvalidation fold: 98/200
# Crossvalidation fold: 99/200
# Crossvalidation fold: 100/200
# Crossvalidation fold: 101/200
# Crossvalidation fold: 102/200
# Crossvalidation fold: 103/200
# Crossvalidation fold: 104/200
# Crossvalidation fold: 105/200
# Crossvalidation fold: 106/200
# Crossvalidation fold: 107/200
# Crossvalidation fold: 108/200
# Crossvalidation fold: 109/200
# Crossvalidation fold: 110/200
# Crossvalidation fold: 111/200
# Crossvalidation fold: 112/200
# Crossvalidation fold: 113/200
# Crossvalidation fold: 114/200
# Crossvalidation fold: 115/200
# Crossvalidation fold: 116/200
# Crossvalidation fold: 117/200
# Crossvalidation fold: 118/200
# Crossvalidation fold: 119/200
# Crossvalidation fold: 120/200
# Crossvalidation fold: 121/200
# Crossvalidation fold: 122/200
# Crossvalidation fold: 123/200
# Crossvalidation fold: 124/200
# Crossvalidation fold: 125/200
# Crossvalidation fold: 126/200
# Crossvalidation fold: 127/200
# Crossvalidation fold: 128/200
# Crossvalidation fold: 129/200
# Crossvalidation fold: 130/200
# Crossvalidation fold: 131/200
# Crossvalidation fold: 132/200
# Crossvalidation fold: 133/200
# Crossvalidation fold: 134/200
# Crossvalidation fold: 135/200
# Crossvalidation fold: 136/200
# Crossvalidation fold: 137/200
# Crossvalidation fold: 138/200
# Crossvalidation fold: 139/200
# Crossvalidation fold: 140/200
# Crossvalidation fold: 141/200
# Crossvalidation fold: 142/200
# Crossvalidation fold: 143/200
# Crossvalidation fold: 144/200
# Crossvalidation fold: 145/200
# Crossvalidation fold: 146/200
# Crossvalidation fold: 147/200
# Crossvalidation fold: 148/200
# Crossvalidation fold: 149/200
# Crossvalidation fold: 150/200
# Crossvalidation fold: 151/200
# Crossvalidation fold: 152/200
# Crossvalidation fold: 153/200
# Crossvalidation fold: 154/200
# Crossvalidation fold: 155/200
# Crossvalidation fold: 156/200
# Crossvalidation fold: 157/200
# Crossvalidation fold: 158/200
# Crossvalidation fold: 159/200
# Crossvalidation fold: 160/200
# Crossvalidation fold: 161/200
# Crossvalidation fold: 162/200
# Crossvalidation fold: 163/200
# Crossvalidation fold: 164/200
# Crossvalidation fold: 165/200
# Crossvalidation fold: 166/200
# Crossvalidation fold: 167/200
# Crossvalidation fold: 168/200
# Crossvalidation fold: 169/200
# Crossvalidation fold: 170/200
# Crossvalidation fold: 171/200
# Crossvalidation fold: 172/200
# Crossvalidation fold: 173/200
# Crossvalidation fold: 174/200
# Crossvalidation fold: 175/200
# Crossvalidation fold: 176/200
# Crossvalidation fold: 177/200
# Crossvalidation fold: 178/200
# Crossvalidation fold: 179/200
# Crossvalidation fold: 180/200
# Crossvalidation fold: 181/200
# Crossvalidation fold: 182/200
# Crossvalidation fold: 183/200
# Crossvalidation fold: 184/200
# Crossvalidation fold: 185/200
# Crossvalidation fold: 186/200
# Crossvalidation fold: 187/200
# Crossvalidation fold: 188/200
# Crossvalidation fold: 189/200
# Crossvalidation fold: 190/200
# Crossvalidation fold: 191/200
# Crossvalidation fold: 192/200
# Crossvalidation fold: 193/200
# Crossvalidation fold: 194/200
# Crossvalidation fold: 195/200
# Crossvalidation fold: 196/200
# Crossvalidation fold: 197/200
# Crossvalidation fold: 198/200
# Crossvalidation fold: 199/200
# Crossvalidation fold: 200/200

# %% [markdown]
# Exercise 7.1.3

# %%
# Load list of names from files
fmale = open('Data/male.txt','r')
ffemale = open('Data/female.txt','r')
mnames = fmale.readlines(); fnames = ffemale.readlines();
names = mnames + fnames
gender = [0]*len(mnames) + [1]*len(fnames)
fmale.close(); ffemale.close();

# Extract X, y and the rest of variables. Include only names of >4 characters.
X = np.zeros((len(names),4))
y = np.zeros((len(names),1))
n=0
for i in range(0,len(names)):
    name = names[i].strip().lower()
    if len(name)>3:
        X[n,:] = [ord(name[0])-ord('a')+1, ord(name[1])-ord('a')+1, ord(name[-2])-ord('a')+1, ord(name[-1])-ord('a')+1]
        y[n,0] = gender[i]
        n+=1
X = X[0:n,:]; y = y[0:n,:];

N, M = X.shape; C = 2
attributeNames = ['1st letter', '2nd letter', 'Next-to-last letter', 'Last letter']
classNames = ['Female', 'Male'];

# %% [markdown]
# Exercise 7.1.4

# %%
y = y.squeeze()

# Naive Bayes classifier parameters
alpha = 1.0         # additive parameter (e.g. Laplace correction)
est_prior = True   # uniform prior (change to True to estimate prior from data)

# K-fold crossvalidation
K = 10
CV = cross_validation.KFold(N,K,shuffle=True)

errors = np.zeros(K)
k=0
for train_index, test_index in CV:
    print('Crossvalidation fold: {0}/{1}'.format(k+1,K))    
    
    # extract training and test set for current CV fold
    X_train = X[train_index,:]
    y_train = y[train_index]
    X_test = X[test_index,:]
    y_test = y[test_index]
    
    nb_classifier = MultinomialNB(alpha=alpha, fit_prior=est_prior)
    nb_classifier.fit(X_train, y_train)
    y_est_prob = nb_classifier.predict_proba(X_test)
    y_est = np.argmax(y_est_prob,1)
    
    errors[k] = np.sum(y_est!=y_test,dtype=float)/y_test.shape[0]
    k+=1
    
# Print the classification error rate
print('Error rate: {0}%'.format(100*np.mean(errors)))
# Out:
# Crossvalidation fold: 1/10
# Crossvalidation fold: 2/10
# Crossvalidation fold: 3/10
# Crossvalidation fold: 4/10
# Crossvalidation fold: 5/10
# Crossvalidation fold: 6/10
# Crossvalidation fold: 7/10
# Crossvalidation fold: 8/10
# Crossvalidation fold: 9/10
# Crossvalidation fold: 10/10
# Error rate: 29.9306814109%
